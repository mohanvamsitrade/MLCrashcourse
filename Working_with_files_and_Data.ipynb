# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanvamsitrade/MLCrashcourse/blob/main/Working_with_files_and_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the usual libraries and connecting to Kaggle for Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
from google.colab import autoviz

# %%
files.upload()
# Out:
#      <input type="file" id="files-76ba4721-7eb3-44b2-805b-40b8335bd3f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76ba4721-7eb3-44b2-805b-40b8335bd3f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d nelgiriyewithana/new-york-housing-market
# Out:
# ...
#   0% 0.00/271k [00:00<?, ?B/s]
# 100% 271k/271k [00:00<00:00, 66.4MB/s]

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !unzip /content/new-york-housing-market.zip
# Out:
# Archive:  /content/new-york-housing-market.zip
#   inflating: NY-House-Dataset.csv

# %%
NY_dataset = pd.read_csv("/content/NY-House-Dataset.csv")

# %%
NY_dataset.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %% [markdown]
# Opening a CSV file from a URL

# %%
import requests
from io import StringIO

url = ""
headers = {}
req = requests.get(url)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-11-d4ac52426283> in <cell line: 6>()
#       4 url = ""
#       5 headers = {}
# ----> 6 req = requests.get(url)
#       7 data = StringIO(req.text)
#       8
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %% [markdown]
# Set Parameters

# %%
# For files which are not csv you can you "sep" to define the data seperating value
# If column names not available for the data you can give as a list using "names"
pd.read_csv("movies.tsv",sep = '\t', names = [])

# %% [markdown]
# Header Parameter

# %%
# Incase if Column Names considered as part of actual data; Use "header" to tell 1st row is actually columns

pd.read_csv('some_data.csv', header = 1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# use_cols parameter

# %%
# Incase of having multiple coulmns you can choose the list of columns needed to be read

pd.read_csv("some_data.csv", usecols=["List of columns needed"])

# %% [markdown]
# **Skiprows/nrows parameter**

# %%
# You can use "skiprows" to not select given rows while reading data

pd.read_csv('/content/sample_data/california_housing_test.csv', skiprows=[0,2])

# using "nrows" we are defining the numbers of rows which needs to be read or taken into dataframe out of the whole data
pd.read_csv('/content/sample_data/california_housing_test.csv', nrows = 100)
# Out:
#       -122.050000  37.370000  27.000000  3885.000000  661.000000  1537.000000  \
# 0         -117.81      33.78       27.0       3589.0       507.0       1484.0
# 1         -118.36      33.82       28.0         67.0        15.0         49.0
# 2         -119.67      36.33       19.0       1241.0       244.0        850.0
# 3         -119.56      36.51       37.0       1018.0       213.0        663.0
# 4         -121.43      38.63       43.0       1009.0       225.0        604.0
# ...           ...        ...        ...          ...         ...          ...
# 2993      -119.86      34.42       23.0       1450.0       642.0       1258.0
# 2994      -118.14      34.06       27.0       5257.0      1082.0       3496.0
# 2995      -119.70      36.30       10.0        956.0       201.0        693.0
# 2996      -117.12      34.10       40.0         96.0        14.0         46.0
# 2997      -119.63      34.42       42.0       1765.0       263.0        753.0
#
# ...

# %% [markdown]
# Encoding Parameter

# %%
# !kaggle datasets download -d himanshupoddar/zomato-bangalore-restaurants
# Out:
# ...
#  91% 81.0M/89.0M [00:01<00:00, 55.0MB/s]
# 100% 89.0M/89.0M [00:01<00:00, 56.0MB/s]

# %%
# !unzip /content/zomato-bangalore-restaurants.zip
# Out:
# Archive:  /content/zomato-bangalore-restaurants.zip
#   inflating: zomato.csv

# %%
zomato_data = pd.read_csv('zomato.csv')
zomato_df = pd.DataFrame(zomato_data)

zomato_df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato_df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato_df["rest_type"]
# Out:
# 0              Casual Dining
# 1              Casual Dining
# 2        Cafe, Casual Dining
# 3                Quick Bites
# 4              Casual Dining
#                 ...
# 51712                    Bar
# 51713                    Bar
# 51714                    Bar
# 51715                    Bar
# 51716     Bar, Casual Dining
# Name: rest_type, Length: 51717, dtype: object

# %%
casual_dining = zomato_df.loc[zomato_df['rest_type'] == "Casual Dining"]

# %%
casual_dining.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
# 6  https://www.zomato.com/bangalore/rosewood-inte...
#
#                                              address  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 6  19/1, New Timberyard Layout, Beside Satellite ...
#
#                                               name online_order book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 4                                    Grand Village           No         No
# ...

# %% [markdown]
# Skip Bad Lines

# %%
# Incase if a line have more values than number of columns you can skip the line

pd.read_csv("some_data.csv", error_bad_lines=False)

# %% [markdown]
# dtypes Parameter

# %%
zomato_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato_df[zomato_df["approx_cost(for two people)"].str.contains('A.*')== True ]
# Out:
# Empty DataFrame
# Columns: [url, address, name, online_order, book_table, rate, votes, phone, location, rest_type, dish_liked, cuisines, approx_cost(for two people), reviews_list, menu_item, listed_in(type), listed_in(city)]
# Index: []

# %%
zomato_df['approx_cost(for two people)'] = zomato_df['approx_cost(for two people)'].fillna(0)

# %%
zomato_df['approx_cost(for two people)'] = zomato_df['approx_cost(for two people)'].to_numeric(errors = 'ignore')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-d04a68464b94> in <cell line: 1>()
# ----> 1 zomato_df['approx_cost(for two people)'] = zomato_df['approx_cost(for two people)'].to_numeric(errors = 'ignore').astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_numeric'

# %%
zomato_df[zomato_df['approx_cost(for two people)'].str.contains('A.*')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-decc9f6db000> in <cell line: 1>()
# ----> 1 zomato_df[zomato_df['approx_cost(for two people)'].str.contains('A.*')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
# -> 3797         if com.is_bool_indexer(key):
#    3798             return self._getitem_bool_array(key)
#    3799
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     133                     # Don't raise on e.g. ["A", "B", np.nan], see
#     134                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135                     raise ValueError(na_msg)
#     136                 return False
#     137             return True
#
# ...

# %% [markdown]
# Handling Dates

# %%
# "parse_dates" helps you in converting date columns which as considered as objects to Dates

pd.read_csv('IPL_data.csv',parse_dates=['date'])

# %% [markdown]
# Using Converters in DataFrame

# %%
# Creating a function to short the name

def rename(name):
  if name == "Casual Dining":
    return "Casual"
  else:
    return name

# %%
rename("Casual Dining")
# Out:
# 'Casual'

# %%
# Now incorporate the above function into our dataframe

pd.read_csv('/content/zomato.csv', converters={'rest_type':rename })
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...
